# %%
import numpy as np
import pandas as pd
import os
import tokenizers
import string
import torch
import transformers
import torch.nn as nn
from torch.nn import functional as F
from tqdm import tqdm
import re

from sklearn.model_selection import train_test_split

# %%
MAX_LEN = 192
TRAIN_BATCH_SIZE = 32
VALID_BATCH_SIZE = 8
EPOCHS = 5
ROBERTA_PATH = "../roberta-base"
TOKENIZER = tokenizers.ByteLevelBPETokenizer(
    vocab_file=f"{ROBERTA_PATH}/vocab.json", 
    merges_file=f"{ROBERTA_PATH}/merges.txt", 
    lowercase=True,
    add_prefix_space=True
)

# %%
class TweetModel(transformers.RobertaModel):
    def __init__(self, conf):
        super(TweetModel, self).__init__(conf)
        self.roberta = transformers.RobertaModel.from_pretrained(ROBERTA_PATH, config=conf)
        self.drop_out = nn.Dropout(0.1)
        self.l0 = nn.Linear(768 * 2, 2)
        torch.nn.init.normal_(self.l0.weight, std=0.02)
    
    def forward(self, ids, mask, token_type_ids):
        _, _, out = self.roberta(
            ids,
            attention_mask=mask,
            token_type_ids=token_type_ids
        )

        out = torch.cat((out[-1], out[-2]), dim=-1)
        out = self.drop_out(out)
        logits = self.l0(out)

        start_logits, end_logits = logits.split(1, dim=-1)

        start_logits = start_logits.squeeze(-1)
        end_logits = end_logits.squeeze(-1)

        return start_logits, end_logits

# %%
def process_data(tweet, selected_text, sentiment, tokenizer, max_len):
    tweet = " " + " ".join(str(tweet).split())
    selected_text = " " + " ".join(str(selected_text).split())

    len_st = len(selected_text) - 1
    idx0 = None
    idx1 = None

    for ind in (i for i, e in enumerate(tweet) if e == selected_text[1]):
        if " " + tweet[ind: ind+len_st] == selected_text:
            idx0 = ind
            idx1 = ind + len_st - 1
            break

    char_targets = [0] * len(tweet)
    if idx0 != None and idx1 != None:
        for ct in range(idx0, idx1 + 1):
            char_targets[ct] = 1
    
    tok_tweet = tokenizer.encode(tweet)
    input_ids_orig = tok_tweet.ids
    tweet_offsets = tok_tweet.offsets
    
    target_idx = []
    for j, (offset1, offset2) in enumerate(tweet_offsets):
        if sum(char_targets[offset1: offset2]) > 0:
            target_idx.append(j)
    
    targets_start = target_idx[0]
    targets_end = target_idx[-1]

    sentiment_id = {
        'positive': 1313,
        'negative': 2430,
        'neutral': 7974
    }
    
    input_ids = [0] + [sentiment_id[sentiment]] + [2] + [2] + input_ids_orig + [2]
    token_type_ids = [0, 0, 0, 0] + [0] * (len(input_ids_orig) + 1)
    mask = [1] * len(token_type_ids)
    tweet_offsets = [(0, 0)] * 4 + tweet_offsets + [(0, 0)]
    targets_start += 4
    targets_end += 4

    padding_length = max_len - len(input_ids)
    if padding_length > 0:
        input_ids = input_ids + ([1] * padding_length)
        mask = mask + ([0] * padding_length)
        token_type_ids = token_type_ids + ([0] * padding_length)
        tweet_offsets = tweet_offsets + ([(0, 0)] * padding_length)
    
    return {
        'ids': input_ids,
        'mask': mask,
        'token_type_ids': token_type_ids,
        'targets_start': targets_start,
        'targets_end': targets_end,
        'orig_tweet': tweet,
        'orig_selected': selected_text,
        'sentiment': sentiment,
        'offsets': tweet_offsets
    }


class TweetDataset:
    def __init__(self, tweet, sentiment, selected_text):
        self.tweet = tweet
        self.sentiment = sentiment
        self.selected_text = selected_text
        self.tokenizer = TOKENIZER
        self.max_len = MAX_LEN
    
    def __len__(self):
        return len(self.tweet)

    def __getitem__(self, item):
        data = process_data(
            self.tweet[item], 
            self.selected_text[item], 
            self.sentiment[item],
            self.tokenizer,
            self.max_len
        )

        return {
            'ids': torch.tensor(data["ids"], dtype=torch.long),
            'mask': torch.tensor(data["mask"], dtype=torch.long),
            'token_type_ids': torch.tensor(data["token_type_ids"], dtype=torch.long),
            'targets_start': torch.tensor(data["targets_start"], dtype=torch.long),
            'targets_end': torch.tensor(data["targets_end"], dtype=torch.long),
            'orig_tweet': data["orig_tweet"],
            'orig_selected': data["orig_selected"],
            'sentiment': data["sentiment"],
            'offsets': torch.tensor(data["offsets"], dtype=torch.long)
        }

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def calculate_jaccard_score(
    original_tweet, 
    target_string, 
    sentiment_val, 
    idx_start, 
    idx_end, 
    offsets,
    verbose=False):
    
    if idx_end < idx_start:
            idx_end = idx_start
    
    filtered_output  = ""
    for ix in range(idx_start, idx_end + 1):
        filtered_output += original_tweet[offsets[ix][0]: offsets[ix][1]]
        if (ix+1) < len(offsets) and offsets[ix][1] < offsets[ix+1][0]:
            filtered_output += " "
# ====
    filtered_output = filtered_output.replace(" .", ".")
    filtered_output = filtered_output.replace(" ?", "?")
    filtered_output = filtered_output.replace(" !", "!")
    filtered_output = filtered_output.replace(" ,", ",")
    filtered_output = filtered_output.replace(" ' ", "'")
    filtered_output = filtered_output.replace(" n't", "n't")
    filtered_output = filtered_output.replace(" 'm", "'m")
    filtered_output = filtered_output.replace(" do not", " don't")
    filtered_output = filtered_output.replace(" 's", "'s")
    filtered_output = filtered_output.replace(" 've", "'ve")
    filtered_output = filtered_output.replace(" 're", "'re")
# ====
    if sentiment_val == "neutral" or len(original_tweet.split()) < 2:
        filtered_output = original_tweet

    
#     if idx_end < idx_start:
#         idx_end = idx_start
    
#     filtered_output  = ""
#     for ix in range(idx_start, idx_end + 1):
#         filtered_output += original_tweet[offsets[ix][0]: offsets[ix][1]]
#         if (ix+1) < len(offsets) and offsets[ix][1] < offsets[ix+1][0]:
#             filtered_output += " "

#     if sentiment_val == "neutral" or len(original_tweet.split()) < 2:
#         filtered_output = original_tweet

#     if sentiment_val != "neutral" and verbose == True:
#         if filtered_output.strip().lower() != target_string.strip().lower():
#             print("********************************")
#             print(f"Output= {filtered_output.strip()}")
#             print(f"Target= {target_string.strip()}")
#             print(f"Tweet= {original_tweet.strip()}")
#             print("********************************")

#     jac = 0
    jac = jaccard(target_string.strip(), filtered_output.strip())
    return jac, filtered_output

# %%
df_test = pd.read_csv("input/train.csv")
df_test.loc[:, "selected_text"] = df_test.text.values

# %%
df_test
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1          Sooo SAD I will miss you here in San Diego!!!  negative
# 2                              my boss is bullying me...  negative
# 3                         what interview! leave me alone  negative
# 4       Sons of ****, why couldn`t they put them on t...  negative
# ...                                                  ...       ...
# 27476   wish we could come see u on Denver  husband l...  negative
# 27477   I`ve wondered about rake to.  The client has ...  negative
# 27478   Yay good for both of you. Enjoy the break - y...  positive
# 27479                         But it was worth it  ****.  positive
# 27480     All this flirting going on - The ATG smiles...   neutral
#
# [27481 rows x 4 columns]

# %%
device = torch.device("cuda")
model_config = transformers.RobertaConfig.from_pretrained(ROBERTA_PATH)
model_config.output_hidden_states = True

# %%
# import gc
# gc.collect()
# torch.cuda.empty_cache()

# %%
model_path = 'src/bins_1104/'

model1 = TweetModel(conf=model_config)
model1.to(device)
model1.load_state_dict(torch.load(model_path+"model_0.bin"))
model1.eval()

model2 = TweetModel(conf=model_config)
model2.to(device)
model2.load_state_dict(torch.load(model_path+"model_1.bin"))
model2.eval()

model3 = TweetModel(conf=model_config)
model3.to(device)
model3.load_state_dict(torch.load(model_path+"model_2.bin"))
model3.eval()

model4 = TweetModel(conf=model_config)
model4.to(device)
model4.load_state_dict(torch.load(model_path+"model_3.bin"))
model4.eval()

model5 = TweetModel(conf=model_config)
model5.to(device)
model5.load_state_dict(torch.load(model_path+"model_4.bin"))
model5.eval()
# Out:
# TweetModel(
#   (embeddings): RobertaEmbeddings(
#     (word_embeddings): Embedding(50265, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (token_type_embeddings): Embedding(1, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (drop_out): Dropout(p=0.1, inplace=False)
#   (l0): Linear(in_features=1536, out_features=2, bias=True)
# )

# %%
final_output = []
jaccard_scores = []

# %%
test_dataset = TweetDataset(
        tweet=df_test.text.values,
        sentiment=df_test.sentiment.values,
        selected_text=df_test.selected_text.values
    )

data_loader = torch.utils.data.DataLoader(
    test_dataset,
    shuffle=False,
    batch_size=VALID_BATCH_SIZE,
    num_workers=1
)


with torch.no_grad():
    tk0 = tqdm(data_loader, total=len(data_loader))
    for bi, d in enumerate(tk0):
        ids = d["ids"]
        token_type_ids = d["token_type_ids"]
        mask = d["mask"]
        sentiment = d["sentiment"]
        orig_selected = d["orig_selected"]
        orig_tweet = d["orig_tweet"]
        targets_start = d["targets_start"]
        targets_end = d["targets_end"]
        offsets = d["offsets"].numpy()

        ids = ids.to(device, dtype=torch.long)
        token_type_ids = token_type_ids.to(device, dtype=torch.long)
        mask = mask.to(device, dtype=torch.long)
        targets_start = targets_start.to(device, dtype=torch.long)
        targets_end = targets_end.to(device, dtype=torch.long)

        outputs_start1, outputs_end1 = model1(
            ids=ids,
            mask=mask,
            token_type_ids=token_type_ids
        )
        
        outputs_start2, outputs_end2 = model2(
            ids=ids,
            mask=mask,
            token_type_ids=token_type_ids
        )
        
        outputs_start3, outputs_end3 = model3(
            ids=ids,
            mask=mask,
            token_type_ids=token_type_ids
        )
        
        outputs_start4, outputs_end4 = model4(
            ids=ids,
            mask=mask,
            token_type_ids=token_type_ids
        )
        
        outputs_start5, outputs_end5 = model5(
            ids=ids,
            mask=mask,
            token_type_ids=token_type_ids
        )
        outputs_start = (outputs_start1 + outputs_start2 + outputs_start3 + outputs_start4 + outputs_start5) / 5
        outputs_end = (outputs_end1 + outputs_end2 + outputs_end3 + outputs_end4 + outputs_end5) / 5
        
        outputs_start = torch.softmax(outputs_start, dim=1).cpu().detach().numpy()
        outputs_end = torch.softmax(outputs_end, dim=1).cpu().detach().numpy()
#         jaccard_scores = []
        for px, tweet in enumerate(orig_tweet):
            selected_tweet = orig_selected[px]
            tweet_sentiment = sentiment[px]
            js, output_sentence = calculate_jaccard_score( #output_sentence
                original_tweet=tweet,
                target_string=selected_tweet,
                sentiment_val=tweet_sentiment,
                idx_start=np.argmax(outputs_start[px, :]),
                idx_end=np.argmax(outputs_end[px, :]),
                offsets=offsets[px]
            )
            final_output.append(output_sentence)
            jaccard_scores.append(js)
# Out:
#   0%|          | 0/3436 [00:00<?, ?it/s]
#   0%|          | 1/3436 [00:00<19:08,  2.99it/s]
#   0%|          | 2/3436 [00:00<17:59,  3.18it/s]
#   0%|          | 3/3436 [00:00<17:01,  3.36it/s]
#   0%|          | 4/3436 [00:01<16:20,  3.50it/s]
#   0%|          | 5/3436 [00:01<15:53,  3.60it/s]
#   0%|          | 6/3436 [00:01<15:35,  3.67it/s]
#   0%|          | 7/3436 [00:01<15:24,  3.71it/s]
#   0%|          | 8/3436 [00:02<15:15,  3.74it/s]
#   0%|          | 9/3436 [00:02<15:09,  3.77it/s]
#   0%|          | 10/3436 [00:02<15:05,  3.78it/s]
#   0%|          | 11/3436 [00:02<15:02,  3.80it/s]
#   0%|          | 12/3436 [00:03<15:01,  3.80it/s]
#   0%|          | 13/3436 [00:03<14:59,  3.81it/s]
#   0%|          | 14/3436 [00:03<14:45,  3.87it/s]
#   0%|          | 15/3436 [00:03<14:36,  3.90it/s]
#   0%|          | 16/3436 [00:04<14:29,  3.93it/s]
#   0%|          | 17/3436 [00:04<14:23,  3.96it/s]
#   1%|          | 18/3436 [00:04<14:19,  3.98it/s]
#   1%|          | 19/3436 [00:04<14:17,  3.99it/s]
#   1%|          | 20/3436 [00:05<14:14,  4.00it/s]
#   1%|          | 21/3436 [00:05<14:13,  4.00it/s]
#   1%|          | 22/3436 [00:05<14:12,  4.01it/s]
#   1%|          | 23/3436 [00:05<14:10,  4.01it/s]
#   1%|          | 24/3436 [00:06<14:10,  4.01it/s]
#   1%|          | 25/3436 [00:06<14:10,  4.01it/s]
#   1%|          | 26/3436 [00:06<14:09,  4.02it/s]
#   1%|          | 27/3436 [00:06<14:09,  4.01it/s]
#   1%|          | 28/3436 [00:07<14:06,  4.03it/s]
#   1%|          | 29/3436 [00:07<14:01,  4.05it/s]
#   1%|          | 30/3436 [00:07<14:01,  4.05it/s]
#   1%|          | 31/3436 [00:07<13:59,  4.06it/s]
#   1%|          | 32/3436 [00:08<13:59,  4.05it/s]
#   1%|          | 33/3436 [00:08<14:00,  4.05it/s]
#   1%|          | 34/3436 [00:08<14:01,  4.04it/s]
#   1%|          | 35/3436 [00:08<14:02,  4.04it/s]
#   1%|          | 36/3436 [00:09<13:59,  4.05it/s]
#   1%|          | 37/3436 [00:09<13:59,  4.05it/s]
#   1%|          | 38/3436 [00:09<13:57,  4.06it/s]
#  99%|█████████▉| 3409/3436 [14:31<00:06,  3.86it/s]
#  99%|█████████▉| 3410/3436 [14:31<00:06,  3.86it/s]
#  99%|█████████▉| 3411/3436 [14:31<00:06,  3.86it/s]
#  99%|█████████▉| 3412/3436 [14:31<00:06,  3.86it/s]
#  99%|█████████▉| 3413/3436 [14:32<00:05,  3.86it/s]
#  99%|█████████▉| 3414/3436 [14:32<00:05,  3.86it/s]
#  99%|█████████▉| 3415/3436 [14:32<00:05,  3.86it/s]
#  99%|█████████▉| 3416/3436 [14:32<00:05,  3.87it/s]
#  99%|█████████▉| 3417/3436 [14:33<00:04,  3.86it/s]
#  99%|█████████▉| 3418/3436 [14:33<00:04,  3.87it/s]
# 100%|█████████▉| 3419/3436 [14:33<00:04,  3.87it/s]
# 100%|█████████▉| 3420/3436 [14:33<00:04,  3.87it/s]
# 100%|█████████▉| 3421/3436 [14:34<00:03,  3.87it/s]
# 100%|█████████▉| 3422/3436 [14:34<00:03,  3.87it/s]
# 100%|█████████▉| 3423/3436 [14:34<00:03,  3.88it/s]
# 100%|█████████▉| 3424/3436 [14:34<00:03,  3.87it/s]
# 100%|█████████▉| 3425/3436 [14:35<00:02,  3.89it/s]
# 100%|█████████▉| 3426/3436 [14:35<00:02,  3.88it/s]
# 100%|█████████▉| 3427/3436 [14:35<00:02,  3.88it/s]
# 100%|█████████▉| 3428/3436 [14:35<00:02,  3.88it/s]
# 100%|█████████▉| 3429/3436 [14:36<00:01,  3.88it/s]
# 100%|█████████▉| 3430/3436 [14:36<00:01,  3.88it/s]
# 100%|█████████▉| 3431/3436 [14:36<00:01,  3.88it/s]
# 100%|█████████▉| 3432/3436 [14:36<00:01,  3.88it/s]
# 100%|█████████▉| 3433/3436 [14:37<00:00,  3.90it/s]
# 100%|█████████▉| 3434/3436 [14:37<00:00,  3.89it/s]
# 100%|██████████| 3436/3436 [14:37<00:00,  3.91it/s]

# %%
sample = pd.read_csv("input/train.csv")
sample.loc[:, 'selected_text_model'] = final_output
sample.loc[:, 'jaccard'] = jaccard_scores
sample.to_csv("src/bins_1104/train_result_jaccard_filtered.csv", index=False)

# %%
tmp = pd.read_csv("src/roberta_base_1104/train_result_jaccard.csv")
# tmp_f = pd.read_csv("src/bins_1104/train_result_jaccard_filtered.csv")

# %%
tmp.head(5)
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                     selected_text_model   jaccard
# 0   I`d have responded, if I were going  1.000000
# 1                              Sooo SAD  0.200000
# 2                              bullying  0.200000
# 3                        leave me alone  0.600000
# 4                         Sons of ****,  0.214286

# %%
tmp.loc[tmp[(tmp.jaccard < 0.8)].index, ['selected_text', 'selected_text_model', 'sentiment']].sentiment.value_counts()
# Out:
# positive    7792
# negative    6932
# Name: sentiment, dtype: int64

# %%
wrong_neutral={}
for i, j in tmp[tmp.sentiment == 'neutral'].loc[:, ['text', 'selected_text']].iterrows():
    if len(str(j[0]).split()) != len(str(j[1]).split()):
        wrong_neutral[i] = len(str(j[0]).split()) - len(str(j[1]).split())

# %%
tmp['cnt_wrong_neutral'] = tmp.index.map(wrong_neutral)

# %%
df_wrong_neutral = tmp.dropna().copy()

# %%
for i in df_wrong_neutral.index:
    res = (set(df_wrong_neutral.loc[i, 'selected_text_model'].split()) - set(df_wrong_neutral.loc[i, 'selected_text'].split()))
#     print(', '.join(list(res)))
    df_wrong_neutral.loc[i, 'wrong_neutral_words'] = ', '.join(list(res))

# %%
tmp[tmp.cnt_wrong_neutral.isna() & (tmp.sentiment=='neutral')]['selected_text'].str.match('x').sum()
# Out:
# 1

# %%
from collections import Counter # 87 http

c=Counter()
for word in df_wrong_neutral.wrong_neutral_words.tolist():
     c[word] += 1

c.most_common(20)
# Out:
# [('x', 19),
#  ('?', 13),
#  ('', 9),
#  ('****', 8),
#  (':', 8),
#  ('lol', 7),
#  ('-', 4),
#  ('!', 4),
#  ('<3', 4),
#  ('http://tweet.sg, -', 3),
#  (';)', 3),
#  ('_carter', 3),
#  (':/', 3),
#  ('it', 2),
#  ('_s', 2),
#  ('_Lia', 2),
#  ('#fb', 2),
#  ('??', 2),
#  ('_1210', 2),
#  ('http://bit.ly/AF8JT', 2)]

# %%
tmp.groupby('sentiment')['jaccard'].describe()
# Out:
#              count      mean       std       min  25%  50%  75%  max
# sentiment
# negative    7781.0  0.995939  0.055909  0.000000  1.0  1.0  1.0  1.0
# neutral    11118.0  0.999795  0.007239  0.571429  1.0  1.0  1.0  1.0
# positive    8582.0  0.995801  0.057080  0.000000  1.0  1.0  1.0  1.0

# %%
import sys
sys.path.insert(0, "/home/pchlq/workspace/models_nlp/sentencepiece-pb2.py")

# %%
import os
import sentencepiece as spm
import sentencepiece_pb2

# %%
sp = spm.SentencePieceProcessor()
model_path = "/home/pchlq/workspace/models_nlp/albert-xxlarge-v1/"
sp.load(os.path.join(model_path, "spiece.model"))
# Out:
# True

# %%
class SentencePieceTokenizer:
    def __init__(self, model_path):
        self.sp = spm.SentencePieceProcessor()
        self.sp.load(os.path.join(model_path, "spiece.model"))
    
    def encode(self, sentence):
        spt = sentencepiece_pb2.SentencePieceText()
        spt.ParseFromString(self.sp.encode_as_serialized_proto(sentence))
        offsets = []
        tokens = []
        for piece in spt.pieces:
            tokens.append(piece.id)
            offsets.append((piece.begin, piece.end))
        return tokens, offsets

# %%
spt = SentencePieceTokenizer(model_path)

# %%
spt.encode("neutral")[0][0]
# Out:
# 8387

# %% [markdown]
# # score analysis

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
for i, j in tmp.iterrows():
    try: 
        tmp.loc[i, 'jaccard'] = (jaccard(j['selected_text'], j['selected_text_model']))
    except:
        tmp.loc[i, 'jaccard'] = np.nan
        print(i)
# Out:
# 314

# %%
tmp.iloc[314, :]
# Out:
# textID                 fdb77c3752
# text                          NaN
# selected_text                 NaN
# sentiment                 neutral
# selected_text_model           nan
# jaccard                       NaN
# Name: 314, dtype: object

# %%
tmp.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                     selected_text_model  jaccard
# 0   I`d have responded, if I were going      1.0
# 1                              Sooo SAD      1.0
# 2                              bullying      0.5
# 3                        leave me alone      1.0
# 4                         Sons of ****,      1.0

# %%
tmp.sentiment.value_counts()
# Out:
# neutral     11118
# positive     8582
# negative     7781
# Name: sentiment, dtype: int64

# %%
tmp.groupby('sentiment')['jaccard'].mean()
# Out:
# sentiment
# negative    0.612771
# neutral     0.976445
# positive    0.599159
# Name: jaccard, dtype: float64

# %% [markdown]
# # neutral

# %%
tmp.loc[tmp.sentiment=='neutral', ['text', 'selected_text', 'selected_text_model', 'jaccard']].sort_values(by='jaccard').head(20)
# Out:
#                                                     text  \
# 18142                                    wow.???? ??????
# 24069                                           G`night!
# 26230   check out review for the movie Fighting - htt...
# 13965                                         hï¿½rlich!
# 25691                                    @_Cheshire_Cat_
# 3263                                    _INTHEMAKING :aw
# 24210                                         BYEEEEE!!!
# 12565   Is it bad that I`m sitting here watching a #P...
# 22458  first up, make up for lost time with jelly. Ja...
# 22815  I am the queen of losing things. Important thi...
# 4141    Morning John, yes I do, however I have a diar...
# 9907   Beer, garden, IPOD, Friday night, shame I`ve g...
# 5053   Sick  Right now very thankful for my chicken s...
# 6998   hmm, anyone else have their iPhone`s earphones...
# 26331    Lol...I am greedy. I`m craving Coldstone again.
# 4655         ???ï¿½ï¿½  ???CE d grade?mock?????, ???????
# 23536  Work is MAD blocking sites! No fun  but they a...
# 17339  _nobel ? ? ?????????????  = ?????? ?????? ????...
# 23038   SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM - never fr...
# 21807   yeah, I was always changing my hair color in ...
#
#                             selected_text  \
# 18142                                wow.
# 24069                             G`night
# 26230                           Hilarious
# 13965                              rlich!
# 25691                      _Cheshire_Cat_
# 3263                                   aw
# 24210                           BYEEEEE!!
# 12565                                 bad
# 22458                              Happeh
# 22815                              losing
# 4141                                sadly
# 9907                                shame
# 5053                                 Sick
# 6998                      disintegrating?
# 26331                           m greedy.
# 4655                    ?CE d grade?mock?
# 23536                        MAD blocking
# 17339                              _nobel
# 23038  SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM
# 21807        . Some good, some baaaaaaaad
#
#                                      selected_text_model   jaccard
# 18142                                    wow.???? ??????  0.000000
# 24069                                           G`night!  0.000000
# 26230   check out review for the movie Fighting - htt...  0.000000
# 13965                                         hï¿½rlich!  0.000000
# 25691                                    @_Cheshire_Cat_  0.000000
# 3263                                    _INTHEMAKING :aw  0.000000
# 24210                                         BYEEEEE!!!  0.000000
# 12565   Is it bad that I`m sitting here watching a #P...  0.045455
# 22458   first up, make up for lost time with jelly. J...  0.050000
# 22815   I am the queen of losing things. Important th...  0.071429
# 4141    Morning John, yes I do, however I have a diar...  0.071429
# 9907    Beer, garden, IPOD, Friday night, shame I`ve ...  0.090909
# 5053    Sick Right now very thankful for my chicken s...  0.090909
# 6998    hmm, anyone else have their iPhone`s earphone...  0.100000
# 26331    Lol...I am greedy. I`m craving Coldstone again.  0.125000
# 4655          ???ï¿½ï¿½ ???CE d grade?mock?????, ???????  0.142857
# 23536   Work is MAD blocking sites! No fun but they a...  0.142857
# 17339   _nobel ? ? ????????????? = ?????? ?????? ????...  0.142857
# 23038   SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM - never fr...  0.142857
# 21807   yeah, I was always changing my hair color in ...  0.142857

# %%
neutral = tmp.loc[tmp.sentiment=='neutral'].dropna().copy()

# %%
# regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
regex = re.compile('[hï¿½]')
neutral[neutral.text.str.contains(regex)].sort_values(by='jaccard')[:20]
# Out:
#            textID                                               text  \
# 26230  01cf51125c   check out review for the movie Fighting - htt...
# 24069  bd085c659b                                           G`night!
# 13965  9d57d8f6d6                                         hï¿½rlich!
# 25691  f7286fdad8                                    @_Cheshire_Cat_
# 12565  5d80bf1e55   Is it bad that I`m sitting here watching a #P...
# 22458  a99c5a9003  first up, make up for lost time with jelly. Ja...
# 4141   f1d8f49520   Morning John, yes I do, however I have a diar...
# 22815  f782648201  I am the queen of losing things. Important thi...
# 9907   fc3b643847  Beer, garden, IPOD, Friday night, shame I`ve g...
# 5053   cc443795be  Sick  Right now very thankful for my chicken s...
# 6998   cf80e6a4e0  hmm, anyone else have their iPhone`s earphones...
# 21807  4d727a948d   yeah, I was always changing my hair color in ...
# 23536  ccce222da3  Work is MAD blocking sites! No fun  but they a...
# 23038  2d059a6bc6   SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM - never fr...
# 4655   d290b62835        ???ï¿½ï¿½  ???CE d grade?mock?????, ???????
# 26025  03c0a20b7a   lol - funny thing is - I don`t even know what...
# 2006   01942ec563  _Ada_Franco I am working again!  Woo hoo!  Ala...
# 13338  70c8ea0595  - It`s time for Kathleen to go to bed... waaaa...
# 25996  6a3bf13772     poor Stuart...    I was wondering where he ...
# 15654  10696c8559  _rade oh no the economy gotcha?  sorry but so ...
#
#                             selected_text sentiment  \
# 26230                           Hilarious   neutral
# 24069                             G`night   neutral
# 13965                              rlich!   neutral
# 25691                      _Cheshire_Cat_   neutral
# 12565                                 bad   neutral
# 22458                              Happeh   neutral
# 4141                                sadly   neutral
# 22815                              losing   neutral
# 9907                                shame   neutral
# 5053                                 Sick   neutral
# 6998                      disintegrating?   neutral
# 21807        . Some good, some baaaaaaaad   neutral
# 23536                        MAD blocking   neutral
# 23038  SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM   neutral
# 4655                    ?CE d grade?mock?   neutral
# 26025                 - I am THAT clueles   neutral
# 2006                      Woo hoo!  Alas,   neutral
# 13338             Have a BLESSED morning.   neutral
# 25996       poor Stuart...    I was wonde   neutral
# 15654                  sorry but so happy   neutral
#
#                                      selected_text_model   jaccard
# 26230   check out review for the movie Fighting - htt...  0.000000
# 24069                                           G`night!  0.000000
# 13965                                         hï¿½rlich!  0.000000
# 25691                                    @_Cheshire_Cat_  0.000000
# 12565   Is it bad that I`m sitting here watching a #P...  0.045455
# 22458   first up, make up for lost time with jelly. J...  0.050000
# 4141    Morning John, yes I do, however I have a diar...  0.071429
# 22815   I am the queen of losing things. Important th...  0.071429
# 9907    Beer, garden, IPOD, Friday night, shame I`ve ...  0.090909
# 5053    Sick Right now very thankful for my chicken s...  0.090909
# 6998    hmm, anyone else have their iPhone`s earphone...  0.100000
# 21807   yeah, I was always changing my hair color in ...  0.142857
# 23536   Work is MAD blocking sites! No fun but they a...  0.142857
# 23038   SCREAAAAAAAAAAAAAAAAAAAAAAAAAAAAAM - never fr...  0.142857
# 4655          ???ï¿½ï¿½ ???CE d grade?mock?????, ???????  0.142857
# 26025   lol - funny thing is - I don`t even know what...  0.153846
# 2006    _Ada_Franco I am working again! Woo hoo! Alas...  0.157895
# 13338   - It`s time for Kathleen to go to bed... waaa...  0.173913
# 25996   poor Stuart... I was wondering where he was! ...  0.190476
# 15654   _rade oh no the economy gotcha? sorry but so ...  0.190476

# %%
tmp.loc[27471, 'text']
# Out:
# 'i`m defying gravity. and nobody in alll of oz, no wizard that there is or was, is ever gonna bring me down'

# %%
neutral.loc[neutral.text.str.match(r'\w+\?').index]
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 5      28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 7      50e14c0bb8                                         Soooo high
# 8      e050245fbd                                        Both of you
# 10     2339a9b08b   as much as i love to be hopeful, i reckon the...
# ...           ...                                                ...
# 27468  a753a93e45  few grilled mushrooms and olives, feta cheese ...
# 27469  ac92790d8b              94 more days till BH comes back to LA
# 27471  15bb120f57  i`m defying gravity. and nobody in alll of oz,...
# 27473  a208770a32   in spoke to you yesterday and u didnt respond...
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment  \
# 0                    I`d have responded, if I were going   neutral
# 5      http://www.dothebouncy.com/smf - some shameles...   neutral
# 7                                             Soooo high   neutral
# 8                                            Both of you   neutral
# 10     as much as i love to be hopeful, i reckon the ...   neutral
# ...                                                  ...       ...
# 27468  few grilled mushrooms and olives, feta cheese ...   neutral
# 27469              94 more days till BH comes back to LA   neutral
# 27471  i`m defying gravity. and nobody in alll of oz,...   neutral
# 27473  in spoke to you yesterday and u didnt respond ...   neutral
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
#                                      selected_text_model   jaccard
# 0                    I`d have responded, if I were going  1.000000
# 5       http://www.dothebouncy.com/smf - some shamele...  1.000000
# 7                                             Soooo high  1.000000
# 8                                            Both of you  1.000000
# 10      as much as i love to be hopeful, i reckon the...  1.000000
# ...                                                  ...       ...
# 27468   few grilled mushrooms and olives, feta cheese...  1.000000
# 27469              94 more days till BH comes back to LA  1.000000
# 27471   i`m defying gravity. and nobody in alll of oz...  1.000000
# 27473   in spoke to you yesterday and u didnt respond...  1.000000
# 27480   All this flirting going on - The ATG smiles. ...  0.833333
#
# [11118 rows x 6 columns]

# %% [markdown]
# # negative

# %%
negative = tmp.loc[tmp.sentiment=='negative'].dropna().copy()

# %%
negative.loc[(tmp.jaccard < .5), ['text', 'selected_text', 'selected_text_model', 'jaccard']].sort_values(by='jaccard')[20:50] # jac_1=722
# Out:
#                                                     text  \
# 14061   lol what bothers me is that i`m messing with ...
# 20771  i`m so sick   bad throat and the WORST toothac...
# 11248  Is getting upset at work cus bindz and j are b...
# 20611  WHAT THE HELL IS GOING ON?!?! Last night and t...
# 20614  hate this **** cold. i can`t stop sneezing. an...
# 24502  Drinking and smoking is very bad.---but im gro...
# 24490   http://www.CultureShockMag.com  shoutz 2  the...
# 14002  doing my english essay (on r&j...wtf) that i s...
# 24418                     gahh!! i`m so tired right now.
# 20677  *sigh* Off 2 bed 2 try 2 get these crummy 2 hr...
# 15503  @_hayles are u serious???? you touched his ***...
# 5188   im tweeting... this is so hard... i dont get i...
# 11115   thats the crazy part - was for 16:30. but rea...
# 5241     dude i will check again but i couldnt find a...
# 11053   DAMMIT. I guess my baby daddy is some imposto...
# 18638         Tired with a headache  me no like sunshine
# 15548          exhausted and sick... my face is greenish
# 5313   mommy coming home from vegas tonight! going to...
# 24291                               are you are a RIOT!!
# 15534  plus it hurts seeing sum1 you love falling for...
# 5213    its not a starfleet one  its not even a romul...
# 24572           i bit my tongue sooo bad...it`s swollen.
# 5555    oh dear.  that is terrible. however, moleskin...
# 5560     will have to wait on the recipe at Simply Re...
# 23746     Know I`m not the only one.  Just harder on me.
# 5968   Oww. Can`t even describe how much my back hurt...
# 20919  My flip flop just broke...walking in downtown ...
# 10747   I wish y`all...unfortunately I won`t be able ...
# 23680   Sounds painful   Sorry you got hurt.. And may...
# 10742  I`m bored... Don`t want to stay home tonight, ...
#
#                         selected_text  \
# 14061  i`m messing with my metabolism
# 20771                         e WORST
# 11248            they won`t let me go
# 20611           this morning SUCKED..
# 20614                            ****
# 24502                   is very bad.-
# 24490                 na b nervvoouus
# 14002                            wtf)
# 24418                          gahh!!
# 20677                          bite..
# 15503                          ****!!
# 5188                        so hard..
# 11115            thats the crazy part
# 5241                       al ****-E-
# 11053                        impostor
# 18638                        headache
# 15548                          sick..
# 5313                  islip her plane
# 24291                           RIOT!
# 15534     im wellllllllllllll gutted.
# 5213                           t! lam
# 24572                      sooo bad..
# 5555       oh dear.  that is terrible
# 5560                        .  Sorrie
# 23746                        st harde
# 5968                           stupid
# 20919                         broke..
# 10747                  .unfortunately
# 23680                            Sorr
# 10742                         bored..
#
#                                      selected_text_model  jaccard
# 14061                                            bothers      0.0
# 20771                                        i`m so sick      0.0
# 11248                                              upset      0.0
# 20611                                          SUCKED...      0.0
# 20614                                               hate      0.0
# 24502                                               bad.      0.0
# 24490                                        nervvoouuss      0.0
# 14002                                            ...wtf)      0.0
# 24418                                              tired      0.0
# 20677                                             crummy      0.0
# 15503                                  ohmygod u ****!!!      0.0
# 5188                                             hard...      0.0
# 11115                                      So. Not. Cool      0.0
# 5241                               i am capital ****-E-D      0.0
# 11053                                            DAMMIT.      0.0
# 18638                                              Tired      0.0
# 15548                              exhausted and sick...      0.0
# 5313                                             KILLME.      0.0
# 24291                                             RIOT!!      0.0
# 15534                                              hurts      0.0
# 5213                                                lame      0.0
# 24572                                             bad...      0.0
# 5555                                           terrible.      0.0
# 5560                                            Sorries!      0.0
# 23746                                        Just harder      0.0
# 5968    Oww. Can`t even describe how much my back hurts.      0.0
# 20919                                           broke...      0.0
# 10747                                   ...unfortunately      0.0
# 23680                                     Sounds painful      0.0
# 10742                                       I`m bored...      0.0
